# %%
# Ivy Pulliam
# Assignment Number: 6.2
# Assign values to variables and send print statements in a while loop then break and increment the value

# %%
guess_me = 7
number = 1

while True:
    if number < guess_me:
        print('too low')
    elif number == guess_me:
        print('found it!')
        break
    else:
        print('oops')
        break
    number += 1
# Out:
# too low
# too low
# too low
# too low
# too low
# too low
# found it!

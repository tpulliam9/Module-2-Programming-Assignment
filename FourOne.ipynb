# %%
# Ivy Pulliam
# Assignment Number: 4.1
# This code will be me choosing a number between 1 and 10 with variables and then doing conditional tests for each guess.

# %%
secret = 6
guess = 5

if guess < secret:
    print("too low")
elif guess > secret:
    print("too high")
else:
    print("just right")
# Out:
# too low

# %%
# Ivy Pulliam
# Assignment Number: 4.2
# Will output the print statements depending on if they're true or false

# %%
small = True
green = False

if small and green:
    print("cherry")
elif small and not green:
    print("pumpkin")
elif not small and green:
    print("pea")
else:
    print("pumpkin")
# Out:
# pumpkin
